# %%
import urllib
import numpy as np
import cv2

# %%
fp= "https://prateekvjoshi.files.wordpress.com/2016/01/2-image.png"

# %%
file= r"C:\Users\warne\Desktop\BC Homework\Final_Project_Img_Analysis\static\uploads\IMG_6525.jpg"
url_response=urllib.request.urlopen(fp)
img_array = np.array(bytearray(url_response.read()), dtype=np.uint8)
img = cv2.imdecode(img_array, 1)
fp= img

# %%
image= cv2.imread(file)

# %%
len(img_array)
# Out:
# 404568

# %%
print(img.shape)
print(image.shape)
# Out:
# (393, 500, 3)
# (3015, 3256, 3)

# %%
i=cv2.imread(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-f50697b9a4da> in <module>()
# ----> 1 i=cv2.imread(img)
#
# TypeError: bad argument type for built-in operation

# %%
import requests
from PIL import Image
url= "https://images.pexels.com/photos/248797/pexels-photo-248797.jpeg?auto=compress&cs=tinysrgb&h=350"

# %%
image_name = 'test2.jpg'
r = requests.get(url)
i = Image.open(StringIO(r.content))
i.save(image_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-bc4dc3be3538> in <module>()
#       1 image_name = 'test2.jpg'
#       2 r = requests.get(url)
# ----> 3 i = Image.open(StringIO(r.content))
#       4 i.save(image_name)
#
# NameError: name 'StringIO' is not defined
